# %% [markdown]
# #Introduction to Data Science for Librarians

# %% [markdown]
# ## Table of Contents
#
# **[Preface](https://github.com/sarahwsutton/Introduction_to_datascience_for_librarians/blob/1219fa89c4a56db1cf40b7445df4c61c4f14ea7e/Preface.ipynb)**
#
# **Chapter 1 - What's in it for librarians?**
#
# 1.1 What is data science?
#
# 1.2 Why learn about data science? What's in is for librarians?
#
# **Chapter 2 - Python programming for data science**
#
# 2.1 Getting started in Google CoLab
#
# 2.2 Syntax
#
# 2.3 Comments
#
# 2.4 Variables and data types
#
# 2.5 Functions and methods
#
# 2.6 Python Libraries and Dataframes
#
# 2.7 Conclusion
#
# **Chapter 3 Contents**
#
# 3.1 Types of data
#
# 3.2 Collecting data from human subjects
#
# 3.3 Sources of existing data
#
# 3.4 Data management
#
# 3.6 Data ethics
#
# 3.6 Conclusion
#
# **References**
